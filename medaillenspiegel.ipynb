# %%
import pandas as pd

# %%
url = "https://www.sportschau.de/live-und-ergebnisse/olympia-2026-mailand-cortina/medaillenspiegel"

tabellen = pd.read_html(url)

print(f"Gefundene Tabellen: {len(tabellen)}")

# es gibt nur eine Tabelle, daher:
df = tabellen[0]
# Out:
# Gefundene Tabellen: 1

# %%
df.head(10)
# Out:
#    Unnamed: 0  Unnamed: 1         Land  Gold  Silber  Bronze  Ges
# 0         1.0         NaN     Norwegen    15       8      10   33
# 1         2.0         NaN      Italien     9       5      12   26
# 2         3.0         NaN          USA     7      11       6   24
# 3         4.0         NaN   Frankreich     6       7       4   17
# 4         5.0         NaN  Niederlande     6       7       2   15
# 5         6.0         NaN     Schweden     6       6       3   15
# 6         7.0         NaN  Deutschland     5       8       8   21
# 7         8.0         NaN   Österreich     5       8       4   17
# 8         9.0         NaN        Japan     5       6      12   23
# 9        10.0         NaN      Schweiz     5       4       3   12

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 1', 'Land', 'Gold', 'Silber', 'Bronze', 'Ges'], dtype='str')

# %%
df = df.drop(["Unnamed: 1"], axis=1)

# %%
df = df.rename(columns={"Unnamed: 0": "Rank", "Ges": "Gesamt"})

# %%
df.columns
# Out:
# Index(['Rank', 'Land', 'Gold', 'Silber', 'Bronze', 'Gesamt'], dtype='str')

# %%
df.head(10)
# Out:
#    Rank         Land  Gold  Silber  Bronze  Gesamt
# 0   1.0     Norwegen    15       8      10      33
# 1   2.0      Italien     9       5      12      26
# 2   3.0          USA     7      11       6      24
# 3   4.0   Frankreich     6       7       4      17
# 4   5.0  Niederlande     6       7       2      15
# 5   6.0     Schweden     6       6       3      15
# 6   7.0  Deutschland     5       8       8      21
# 7   8.0   Österreich     5       8       4      17
# 8   9.0        Japan     5       6      12      23
# 9  10.0      Schweiz     5       4       3      12

# %%
# df = df.astype({"Rank": "int32"})
# Das scheitert an der Fortsetzung eines Platzes bei Gleichstand
# Replace NaN ... ?

# %%
df.to_csv("medaillenspiege.csv", index=None)

# %%
# df["Rank"]
